# %% [markdown]
# # Python Programming Fundamentals

# %% [markdown]
# ## Introduction to Python

# %% [markdown]
# **Giving Instructions to computers**
# - Programming is about providing computers with a set of step by step instructions to accomplish a specific task
# - These instructions involve logic, decision making and repetition. Its like creating a flowchart where different paths lead to different outcomes depending on the choices made along the way
# - To handle data, programming languages offer variables and data structures
#     - Variables store information like numbers or text
#     - Data structures organize collections of data
#
# **Programming Languages**
# - Programmers use various programming languages to communicate with computes
#     - Java, C+++, JavaScript, Python
# - Choosing Programming Language
#     - Type of applcation
#     - Prior experience
#     - Specific requirements of the project
# - Why Python
#     - Simplicity
#     - Versatility
#     - Widespread use

# %% [markdown]
# ### Why Python

# %% [markdown]
# - Python is a high level programming language known for its redability and ease of use
#
# **Python**
# ```python
# length = 10
# width = 5
# area = length*width
# print("The area of the rectangle is :", area)
# ```
# **C++**
# ```cpp
# #include <iostram>
# int main(){
#     int length = 10;
#     int width = 5;
#     int area = length * width;
#     std::cout<< "The area of the rectangle is :" << area << std::endl;
#     return 0;
# }

# %% [markdown]
# **Python's defining Characterstics**
# - Interpreted languages
# - High level language
# - Object Oriented Programming
#
# **Python Usecases**
# 1. Web Development => Django, Flask
# 2. Datasciene => NumPy, Pandas, PyTorch
# 3. Automation and Scripting
# 4. Game Dev
# 5. Scientific Computing

# %% [markdown]
# ## Python Basics

# %% [markdown]
# ### Controling the flow: Conditional statements and loops

# %% [markdown]
# ### Organizing Data

# %% [markdown]
# ## Functions and modules

# %% [markdown]
# ### Functions, classes, and modules

# %% [markdown]
# ### Organizing Code: Functions in action

# %% [markdown]
# ### Breaking down problems with functions

# %% [markdown]
# ### Modules and libraries

# %% [markdown]
# ## Data structures in Python

# %% [markdown]
# ### Understanding data structures

# %% [markdown]
# ### Putting data structures to work

# %% [markdown]
# ### Algorithms and lists: Sorting and searching

# %% [markdown]
# ### Data structure selection

# %% [markdown]
# ## Error handling and debugging

# %% [markdown]
# ### Common Python exceptions

# %% [markdown]
# ### Basic debugging techniques

# %% [markdown]
# ### Exception handling in Python

# %% [markdown]
# ### A systematic appproach

# %% [markdown]
# ## Testing basics and version control

# %% [markdown]
# ### Introduction to unit testing

# %% [markdown]
# ### Pytest
